# %%
import numpy as np
import pandas as pd
import glob
import tensorflow as tf
from tensorflow.keras import layers, losses
import os
import time

# %%
os.environ["CUDA_VISIBLE_DEVICES"] = "2"

# %% [raw]
# #File = 1
# #prFileName = 'dataRssi_at_%d.txt'%File
# #dirName = '/home/lyt/gnss_wifi/gnss/20201022/indoor/wifi/'
# #outputname = 'outplot/1out_in'

# %%
datas = glob.glob('20201022/indoor/wifi/dataRssi_at_*.txt')

# %% [raw]
# datas[0].split("/")[-1].split("_")[-1].split(".")[0]

# %% [raw]
# load_data = np.loadtxt(datas[0])
# m = load_data[:,-15:-12][0]/100
# o = load_data[:,-12:-9][0]/100
# a = load_data[:,-9:-6][0]/100
# g = load_data[:,-6:-3][0]/100
# gra = load_data[:,-3:][0]/100

# %%
def getRotationMatrix(gra,m):
    Ax = gra[0]
    Ay = gra[1]
    Az = gra[2]
    Ex = m[0]
    Ey = m[1]
    Ez = m[2]
    Hx = Ey*Az - Ez*Ay
    Hy = Ez*Ax - Ex*Az
    Hz = Ex*Ay - Ey*Ax
    normH = np.sqrt(Hx*Hx + Hy*Hy + Hz*Hz)
    if normH < 0.1:
        return False
    invH = 1.0 / normH
    Hx *= invH
    Hy *= invH
    Hz *= invH
    invA = 1.0 / np.sqrt(Ax*Ax + Ay*Ay + Az*Az)
    Ax *= invA
    Ay *= invA
    Az *= invA
    Mx = Ay*Hz - Az*Hy
    My = Az*Hx - Ax*Hz
    Mz = Ax*Hy - Ay*Hx
    R = np.array([Hx,Hy,Hz,Mx,My,Mz,Ax,Ay,Az])
    return R

# %%
train_data = []
train_label = []
for data in datas:
    load_data = np.loadtxt(data)#f.read()
    gras = load_data[:,-3:]/100
    ms = load_data[:,-15:-12]/100
    for gra,m in zip(gras,ms):
        R = getRotationMatrix(gra,m)
        gm = np.dot(R.reshape(3,3),m.reshape(3,1))
        train_data.append(gm)
        train_label.append(data.split("/")[-1].split("_")[-1].split(".")[0])


train_data = np.array(train_data).astype('float32')
train_data = train_data.reshape(-1,3)
train_data = (train_data - train_data.mean(axis=0)) / train_data.std(axis = 0)
train_label = np.array(pd.get_dummies(train_label)).astype('float32')
#train_label = train_label.reshape(len(train_label),1)
train_val_split = np.random.rand(len(train_data)) < 0.70
train_x = train_data[train_val_split]
train_y = train_label[train_val_split]
val_x = train_data[~train_val_split]
val_y = train_label[~train_val_split]
BUFFER_SIZE = train_x.shape[0]
BATCH_SIZE = train_x.shape[0]
train_dataset = tf.data.Dataset.from_tensor_slices((train_x,train_y))
train_dataset = train_dataset.shuffle(BUFFER_SIZE).batch(BATCH_SIZE)
valid_dataset = tf.data.Dataset.from_tensor_slices((val_x,val_x)).batch(len(val_x))

# %%
class DenseTranspose(tf.keras.layers.Layer):
    def __init__(self, dense, activation=None, **kwargs):
        self.dense = dense
        self.activation = tf.keras.activations.get(activation)
        super().__init__(**kwargs)
    def build(self, batch_input_shape):
        self.biases = self.add_weight(name='bias',shape=[self.dense.input_shape[-1]],initializer="zeros")
        super().build(batch_input_shape)
    def call(self, inputs):
        z = tf.matmul(inputs, self.dense.weights[0], transpose_b = True)
        return self.activation(z + self.biases)

# %%
#mirrored_strategy = tf.distribute.MirroredStrategy(devices=["/gpu:0","/gpu:1"])
#with mirrored_strategy.scope():

input = tf.keras.layers.Input(shape=(3), name='input_layer1')
#flatten = tf.keras.layers.Flatten()(input)
dense1 = tf.keras.layers.Dense(8, activation='relu')
dense2 = tf.keras.layers.Dense(12, activation='relu')
dense3 = tf.keras.layers.Dense(16, activation='relu')
model_encoder = dense1(input)
model_encoder = dense2(model_encoder)
model_encoder = dense3(model_encoder)
model_down = tf.keras.Model(inputs=[input], outputs=model_encoder,name = "encoder")#input1, input2,input3,input4,input5,input6,input7,input8,input9,input10
#model_down.summary()
#input_encoder = tf.keras.layers.Input(shape=(15), name='input_layer2')
input2 = tf.keras.layers.Input(shape=(16), name='input_layer2')
model_decoder = DenseTranspose(dense3, activation = 'relu')(input2)
model_decoder = DenseTranspose(dense2, activation = 'relu')(model_decoder)
model_decoder = DenseTranspose(dense1, activation = 'relu')(model_decoder)
model_up = tf.keras.Model(inputs=[input2], outputs=model_decoder,name = "decoder")

#model_encoder_decoder.summary()
input3 = tf.keras.layers.Input(shape=(16), name='input_layer3')
model_ann = tf.keras.layers.Dense(16, activation='relu')(input3)
model_ann = tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)(model_ann)
model_ann = tf.keras.layers.Dense(16, activation='relu')(model_ann)
model_ann = tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)(model_ann)
model_ann = tf.keras.layers.Dense(16, activation='relu')(model_ann)
#model_ann = tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)(model_ann)
#model_ann = tf.keras.layers.Dense(16, activation='relu')(model_ann)
#model_ann = tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)(model_ann)
#model_ann = tf.keras.layers.Dense(16, activation='relu')(model_ann)
#model_ann = tf.keras.layers.Dropout(0.5, noise_shape=None, seed=None)(model_ann)
model_ann = tf.keras.layers.Dense(9, activation='softmax')(model_ann)
model_ANN = tf.keras.Model(inputs=[input3], outputs=model_ann,name = "ann")

input_full = tf.keras.layers.Input(shape=(3), name='input_layer4')
encoder_out = model_down(input_full)
decoder_out = model_up(encoder_out)
ann_out = model_ANN(encoder_out)
#model_encoder_decoder_ann = tf.keras.Model(inputs=[input_full],outputs=[decoder_out],name = 'encoder_decoder_ann')
model_encoder_decoder_ann = tf.keras.Model(inputs=[input_full],outputs=[decoder_out,ann_out],name = 'encoder_decoder_ann')
#optimizer = tf.keras.optimizers.SGD(learning_rate=1e-2, momentum=1e-5)

# %%
model_encoder_decoder_ann.summary()
# Out:
# Model: "encoder_decoder_ann"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_layer4 (InputLayer)       [(None, 3)]          0
# __________________________________________________________________________________________________
# encoder (Model)                 (None, 16)           348         input_layer4[0][0]
# __________________________________________________________________________________________________
# decoder (Model)                 (None, 3)            371         encoder[1][0]
# __________________________________________________________________________________________________
# ann (Model)                     (None, 9)            969         encoder[1][0]
# ==================================================================================================
# Total params: 1,340
# Trainable params: 1,340
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
len(model_encoder_decoder_ann.trainable_variables)
# Out:
# 17

# %%
for i in range(17):
    print(model_encoder_decoder_ann.trainable_variables[i].shape)
# Out:
# (3, 8)
# (8,)
# (8, 12)
# (12,)
# (12, 16)
# (16,)
# (12,)
# (8,)
# (3,)
# (16, 16)
# (16,)
# (16, 16)
# (16,)
# (16, 16)
# (16,)
# (16, 9)
# (9,)

# %%
shared_vars = model_encoder_decoder_ann.trainable_variables[:6]
decode_vars = model_encoder_decoder_ann.trainable_variables[6:9]
ann_vars = model_encoder_decoder_ann.trainable_variables[9:]

# %%
def model_loss(output,t_x,t_y):
    #print("in loss")
    output_AE , output_label = output
    #output_AE = output
    mse = losses.MeanSquaredError()
    AE_loss = mse(t_x,output_AE)
    ann_loss =losses.categorical_crossentropy(t_y,output_label)
    total_loss = AE_loss*100 + ann_loss
    
    return AE_loss,ann_loss

# %%
learning_rate_A = tf.keras.optimizers.schedules.ExponentialDecay(
initial_learning_rate=1e-4, decay_steps=5000, decay_rate=0.9)
optimizer_A = tf.optimizers.SGD(learning_rate=learning_rate_A , momentum=1e-5)
learning_rate_B = tf.keras.optimizers.schedules.ExponentialDecay(
initial_learning_rate=1e-3, decay_steps=10000, decay_rate=0.8)
optimizer_B = tf.optimizers.Adam(learning_rate=1e-3)#learning_rate_B)

# %%
#@tf.function

def train_step(t_x,t_y):
  
    with tf.GradientTape() as AE_tape,tf.GradientTape() as ANN_tape:
        output = model_encoder_decoder_ann(t_x, training=True)
        #AE_loss = model_loss(output,t_o,t_y)
        AE_loss,ANN_loss = model_loss(output,t_x,t_y)
        #gradients = tape.gradient(total_loss, shared_vars+decode_vars)
        #optimizer_A.apply_gradients(zip(gradients, shared_vars+decode_vars))

    if np.random.rand() < 0.5:
        #print("AE")
        gradients_AE = AE_tape.gradient(AE_loss, shared_vars+decode_vars)
        #gradients_AE = [tf.clip_by_value(g, -1,1) for g in gradients_AE]

        #print("AE gradient : ",gradients_AE)
        optimizer_A.apply_gradients(zip(gradients_AE, shared_vars+decode_vars))
    
    else:
        #print("ANN")
        gradients_ANN = ANN_tape.gradient(ANN_loss, shared_vars+ann_vars)
        #print("ANN gradient : ",gradients_ANN)
        #gradients_ANN = [tf.clip_by_value(g, -1,1) for g in gradients_ANN] 
        optimizer_B.apply_gradients(zip(gradients_ANN, shared_vars+ann_vars))
    
    return np.array(AE_loss).mean(),np.array(ANN_loss).mean()

# %%
checkpoint_dir = './magnetic_checkpoints_1127_1'
checkpoint_prefix = os.path.join(checkpoint_dir, "ckpt_dropout_model_{epoch}")
checkpoint = tf.train.Checkpoint(optimizerA=optimizer_A,
                                 optimizerB=optimizer_B,
                                 model_encoder_decoder_ann=model_encoder_decoder_ann,
                                 model_down=model_down)

# %%
class PrintLR(tf.keras.callbacks.Callback):
  def on_epoch_end(self, epoch, logs=None):
    print('\nLearning rate for epoch {} is {}'.format(epoch + 1,
                                                      model_encoder_decoder.optimizer.lr.numpy()))

# %%
def validation(v_x,v_y):
    output = model_encoder_decoder_ann(v_x)
    #output_AE = output
    output_AE , output_label = output
    mse = losses.MeanSquaredError()
    AE_loss = mse(v_x,output_AE)
    ann_loss = losses.categorical_crossentropy(v_y,output_label)
    total_loss = AE_loss*100 + ann_loss
    #print(output_label[200])
    #print(v_y[200])
    #print(ann_loss)
    #print("AE loss : {},".format(np.array(AE_loss).mean()))
    print("AE loss : {}, ANN loss : {}, Total loss : {}".format(np.array(AE_loss).mean(),np.array(ann_loss).mean(),np.array(total_loss).mean()))

# %% [raw]
# validation(val_x,val_o,val_y)

# %%
val_x.shape
# Out:
# (390, 3)

# %%
def train(epochs):
  for epoch in range(epochs):
    start = time.time()
    all_AE = []
    all_ANN =[]
    for x,y in train_dataset:
        #AE_loss = train_step(x,y)
        AE_loss,ANN_loss = train_step(x,y)
        all_AE.append(AE_loss)
        all_ANN.append(ANN_loss)
    #print("train AE loss : {}".format(np.array(all_AE).mean()))
    print("train AE loss : {}, train ANN loss : {}".format(np.array(all_AE).mean(),np.array(all_ANN).mean()))
    validation(val_x,val_y)
    checkpoint.save(file_prefix=checkpoint_prefix)
    print("learning rate A : ",optimizer_A._decayed_lr(tf.float32))
    print("learning rate B : ",optimizer_B._decayed_lr(tf.float32))
    print(f'Time for epoch {epoch + 1} is {time.time() - start:.4f} sec')

# %%
train(2000)
# Out:
# train AE loss : 0.8132616877555847, train ANN loss : 1.8313456773757935
# AE loss : 0.788556694984436, ANN loss : 1.7316886186599731, Total loss : 80.58735656738281
# learning rate A :  tf.Tensor(9.976216e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1 is 0.0814 sec
# train AE loss : 0.8097912073135376, train ANN loss : 1.823743462562561
# AE loss : 0.7884912490844727, ANN loss : 1.7316755056381226, Total loss : 80.58080291748047
# learning rate A :  tf.Tensor(9.976006e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 2 is 0.0559 sec
# train AE loss : 0.8097185492515564, train ANN loss : 1.8259259462356567
# AE loss : 0.7884259223937988, ANN loss : 1.7316625118255615, Total loss : 80.57425689697266
# learning rate A :  tf.Tensor(9.975796e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 3 is 0.0554 sec
# train AE loss : 0.8096458315849304, train ANN loss : 1.8441160917282104
# AE loss : 0.7853811383247375, ANN loss : 1.7244304418563843, Total loss : 80.26254272460938
# learning rate A :  tf.Tensor(9.975796e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 4 is 0.0595 sec
# train AE loss : 0.8063263893127441, train ANN loss : 1.8206082582473755
# AE loss : 0.7823538184165955, ANN loss : 1.717059850692749, Total loss : 79.95244598388672
# learning rate A :  tf.Tensor(9.975796e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 5 is 0.0576 sec
# train AE loss : 0.8030164837837219, train ANN loss : 1.8197993040084839
# AE loss : 0.7822883725166321, ANN loss : 1.7170475721359253, Total loss : 79.94588470458984
# learning rate A :  tf.Tensor(9.975586e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 6 is 0.0557 sec
# train AE loss : 0.802943766117096, train ANN loss : 1.820279836654663
# AE loss : 0.7822230458259583, ANN loss : 1.7170354127883911, Total loss : 79.93934631347656
# learning rate A :  tf.Tensor(9.975375e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 7 is 0.0558 sec
# train AE loss : 0.80287104845047, train ANN loss : 1.8051056861877441
# AE loss : 0.7821577191352844, ANN loss : 1.7170231342315674, Total loss : 79.93279266357422
# learning rate A :  tf.Tensor(9.9751654e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 8 is 0.0570 sec
# train AE loss : 0.8027984499931335, train ANN loss : 1.8144530057907104
# AE loss : 0.7820924520492554, ANN loss : 1.7170109748840332, Total loss : 79.92625427246094
# learning rate A :  tf.Tensor(9.974955e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 9 is 0.0567 sec
# train AE loss : 0.8027257323265076, train ANN loss : 1.8309838771820068
# AE loss : 0.7820271253585815, ANN loss : 1.71699857711792, Total loss : 79.91970825195312
# learning rate A :  tf.Tensor(9.974745e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 10 is 0.0574 sec
# train AE loss : 0.8026533126831055, train ANN loss : 1.8292254209518433
# AE loss : 0.7819617390632629, ANN loss : 1.7169864177703857, Total loss : 79.91316223144531
# learning rate A :  tf.Tensor(9.9745346e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 11 is 0.0557 sec
# train AE loss : 0.8025805950164795, train ANN loss : 1.8275386095046997
# AE loss : 0.7818965911865234, ANN loss : 1.716974139213562, Total loss : 79.9066390991211
# learning rate A :  tf.Tensor(9.974324e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 12 is 0.0757 sec
# train AE loss : 0.8025079965591431, train ANN loss : 1.8357511758804321
# AE loss : 0.778998613357544, ANN loss : 1.709898591041565, Total loss : 79.6097640991211
# learning rate A :  tf.Tensor(9.974324e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 13 is 0.0574 sec
# train AE loss : 0.799382209777832, train ANN loss : 1.8056983947753906
# AE loss : 0.7789329290390015, ANN loss : 1.7098865509033203, Total loss : 79.60317993164062
# learning rate A :  tf.Tensor(9.974115e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 14 is 0.0560 sec
# train AE loss : 0.7993093729019165, train ANN loss : 1.815965175628662
# AE loss : 0.7759454250335693, ANN loss : 1.7029210329055786, Total loss : 79.2974624633789
# learning rate A :  tf.Tensor(9.974115e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 15 is 0.0575 sec
# train AE loss : 0.7961761355400085, train ANN loss : 1.8164191246032715
# AE loss : 0.7758791446685791, ANN loss : 1.7029093503952026, Total loss : 79.29082489013672
# learning rate A :  tf.Tensor(9.9739045e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 16 is 0.0558 sec
# train AE loss : 0.7961028218269348, train ANN loss : 1.8059008121490479
# AE loss : 0.7730909585952759, ANN loss : 1.6961685419082642, Total loss : 79.00526428222656
# learning rate A :  tf.Tensor(9.9739045e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 17 is 0.0572 sec
# train AE loss : 0.7931816577911377, train ANN loss : 1.8034878969192505
# AE loss : 0.77068692445755, ANN loss : 1.6895442008972168, Total loss : 78.75823974609375
# learning rate A :  tf.Tensor(9.9739045e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 18 is 0.0562 sec
# train AE loss : 0.7906543612480164, train ANN loss : 1.7859554290771484
# AE loss : 0.7682819962501526, ANN loss : 1.6830024719238281, Total loss : 78.51119995117188
# learning rate A :  tf.Tensor(9.9739045e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 19 is 0.0581 sec
# train AE loss : 0.78813636302948, train ANN loss : 1.7842235565185547
# AE loss : 0.7661976218223572, ANN loss : 1.6765440702438354, Total loss : 78.29630279541016
# learning rate A :  tf.Tensor(9.9739045e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 20 is 0.0564 sec
# train AE loss : 0.785950243473053, train ANN loss : 1.7769516706466675
# AE loss : 0.7661242485046387, ANN loss : 1.6765336990356445, Total loss : 78.28895568847656
# learning rate A :  tf.Tensor(9.9736935e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 21 is 0.0567 sec
# train AE loss : 0.7858690023422241, train ANN loss : 1.8030589818954468
# AE loss : 0.7660508155822754, ANN loss : 1.6765233278274536, Total loss : 78.28160095214844
# learning rate A :  tf.Tensor(9.973484e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 22 is 0.0551 sec
# train AE loss : 0.78578782081604, train ANN loss : 1.7555885314941406
# AE loss : 0.7640430331230164, ANN loss : 1.6701500415802002, Total loss : 78.07445526123047
# learning rate A :  tf.Tensor(9.973484e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 23 is 0.0585 sec
# train AE loss : 0.7836874723434448, train ANN loss : 1.7777246236801147
# AE loss : 0.7623140215873718, ANN loss : 1.663933277130127, Total loss : 77.89533233642578
# learning rate A :  tf.Tensor(9.973484e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 24 is 0.0572 sec
# train AE loss : 0.7818796634674072, train ANN loss : 1.7555887699127197
# AE loss : 0.7606686353683472, ANN loss : 1.6578598022460938, Total loss : 77.72472381591797
# learning rate A :  tf.Tensor(9.973484e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 25 is 0.0576 sec
# train AE loss : 0.780171811580658, train ANN loss : 1.767920970916748
# AE loss : 0.7605908513069153, ANN loss : 1.6578500270843506, Total loss : 77.71693420410156
# learning rate A :  tf.Tensor(9.973274e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 26 is 0.0567 sec
# train AE loss : 0.7800862193107605, train ANN loss : 1.7753307819366455
# AE loss : 0.7605131268501282, ANN loss : 1.6578400135040283, Total loss : 77.70915222167969
# learning rate A :  tf.Tensor(9.973064e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 27 is 0.0572 sec
# train AE loss : 0.7800007462501526, train ANN loss : 1.784375786781311
# AE loss : 0.759069561958313, ANN loss : 1.6519159078598022, Total loss : 77.55887603759766
# learning rate A :  tf.Tensor(9.973064e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 28 is 0.0577 sec
# train AE loss : 0.7784901857376099, train ANN loss : 1.7618077993392944
# AE loss : 0.7589906454086304, ANN loss : 1.6519060134887695, Total loss : 77.55097198486328
# learning rate A :  tf.Tensor(9.972853e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 29 is 0.0560 sec
# train AE loss : 0.7784034609794617, train ANN loss : 1.7659908533096313
# AE loss : 0.7577738165855408, ANN loss : 1.6461822986602783, Total loss : 77.42356872558594
# learning rate A :  tf.Tensor(9.972853e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 30 is 0.0586 sec
# train AE loss : 0.7771586179733276, train ANN loss : 1.7688435316085815
# AE loss : 0.7564917802810669, ANN loss : 1.6405212879180908, Total loss : 77.2896957397461
# learning rate A :  tf.Tensor(9.972853e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 31 is 0.0575 sec
# train AE loss : 0.7758177518844604, train ANN loss : 1.7587425708770752
# AE loss : 0.7551482319831848, ANN loss : 1.6348100900650024, Total loss : 77.14964294433594
# learning rate A :  tf.Tensor(9.972853e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 32 is 0.0568 sec
# train AE loss : 0.7744129300117493, train ANN loss : 1.7410041093826294
# AE loss : 0.7550652027130127, ANN loss : 1.6347999572753906, Total loss : 77.14132690429688
# learning rate A :  tf.Tensor(9.972643e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 33 is 0.0555 sec
# train AE loss : 0.7743217945098877, train ANN loss : 1.7657465934753418
# AE loss : 0.7549822926521301, ANN loss : 1.6347897052764893, Total loss : 77.13302612304688
# learning rate A :  tf.Tensor(9.972433e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 34 is 0.0572 sec
# train AE loss : 0.7742308378219604, train ANN loss : 1.7433576583862305
# AE loss : 0.7548993825912476, ANN loss : 1.634779453277588, Total loss : 77.12471771240234
# learning rate A :  tf.Tensor(9.972223e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 35 is 0.0554 sec
# train AE loss : 0.7741400003433228, train ANN loss : 1.7273863554000854
# AE loss : 0.7548165321350098, ANN loss : 1.6347692012786865, Total loss : 77.11641693115234
# learning rate A :  tf.Tensor(9.972013e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 36 is 0.0552 sec
# train AE loss : 0.7740491032600403, train ANN loss : 1.7373874187469482
# AE loss : 0.7534663081169128, ANN loss : 1.6288913488388062, Total loss : 76.97551727294922
# learning rate A :  tf.Tensor(9.972013e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 37 is 0.0579 sec
# train AE loss : 0.7726446986198425, train ANN loss : 1.7276731729507446
# AE loss : 0.7533824443817139, ANN loss : 1.6288808584213257, Total loss : 76.96712493896484
# learning rate A :  tf.Tensor(9.971803e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 38 is 0.0563 sec
# train AE loss : 0.7725529074668884, train ANN loss : 1.7268224954605103
# AE loss : 0.7532986998558044, ANN loss : 1.6288707256317139, Total loss : 76.958740234375
# learning rate A :  tf.Tensor(9.971593e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 39 is 0.0559 sec
# train AE loss : 0.7724611759185791, train ANN loss : 1.727083683013916
# AE loss : 0.7517442107200623, ANN loss : 1.6230759620666504, Total loss : 76.79750061035156
# learning rate A :  tf.Tensor(9.971593e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 40 is 0.0564 sec
# train AE loss : 0.7707871794700623, train ANN loss : 1.734999656677246
# AE loss : 0.7516596913337708, ANN loss : 1.6230660676956177, Total loss : 76.78903198242188
# learning rate A :  tf.Tensor(9.971383e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 41 is 0.0584 sec
# train AE loss : 0.7706940770149231, train ANN loss : 1.721848964691162
# AE loss : 0.7515754699707031, ANN loss : 1.6230560541152954, Total loss : 76.78060150146484
# learning rate A :  tf.Tensor(9.9711724e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 42 is 0.0566 sec
# train AE loss : 0.7706013917922974, train ANN loss : 1.7361195087432861
# AE loss : 0.7498633861541748, ANN loss : 1.617080807685852, Total loss : 76.6034164428711
# learning rate A :  tf.Tensor(9.9711724e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 43 is 0.0576 sec
# train AE loss : 0.768764078617096, train ANN loss : 1.7328840494155884
# AE loss : 0.7497784495353699, ANN loss : 1.6170707941055298, Total loss : 76.59491729736328
# learning rate A :  tf.Tensor(9.970962e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 44 is 0.0555 sec
# train AE loss : 0.7686700224876404, train ANN loss : 1.7222365140914917
# AE loss : 0.7482718229293823, ANN loss : 1.6111103296279907, Total loss : 76.43829345703125
# learning rate A :  tf.Tensor(9.970962e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 45 is 0.0599 sec
# train AE loss : 0.7670668363571167, train ANN loss : 1.724841833114624
# AE loss : 0.7481862902641296, ANN loss : 1.6111005544662476, Total loss : 76.42972564697266
# learning rate A :  tf.Tensor(9.9707526e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 46 is 0.0562 sec
# train AE loss : 0.7669726610183716, train ANN loss : 1.7283143997192383
# AE loss : 0.7467607259750366, ANN loss : 1.6051901578903198, Total loss : 76.28125762939453
# learning rate A :  tf.Tensor(9.9707526e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 47 is 0.0573 sec
# train AE loss : 0.7654678225517273, train ANN loss : 1.71654212474823
# AE loss : 0.7453979253768921, ANN loss : 1.5992828607559204, Total loss : 76.13907623291016
# learning rate A :  tf.Tensor(9.9707526e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 48 is 0.0572 sec
# train AE loss : 0.7640413641929626, train ANN loss : 1.6938602924346924
# AE loss : 0.7440463900566101, ANN loss : 1.593359351158142, Total loss : 75.99799346923828
# learning rate A :  tf.Tensor(9.9707526e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 49 is 0.0584 sec
# train AE loss : 0.7626078128814697, train ANN loss : 1.7160195112228394
# AE loss : 0.7426992058753967, ANN loss : 1.587719440460205, Total loss : 75.8576431274414
# learning rate A :  tf.Tensor(9.9707526e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 50 is 0.0569 sec
# train AE loss : 0.7611609101295471, train ANN loss : 1.7020128965377808
# AE loss : 0.7426065802574158, ANN loss : 1.5877103805541992, Total loss : 75.8483657836914
# learning rate A :  tf.Tensor(9.970542e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 51 is 0.0554 sec
# train AE loss : 0.7610599398612976, train ANN loss : 1.6963409185409546
# AE loss : 0.7425141334533691, ANN loss : 1.5877015590667725, Total loss : 75.839111328125
# learning rate A :  tf.Tensor(9.970332e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 52 is 0.0575 sec
# train AE loss : 0.7609589099884033, train ANN loss : 1.7054985761642456
# AE loss : 0.741262674331665, ANN loss : 1.5820647478103638, Total loss : 75.70833587646484
# learning rate A :  tf.Tensor(9.970332e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 53 is 0.0565 sec
# train AE loss : 0.7595914006233215, train ANN loss : 1.698241114616394
# AE loss : 0.7411695718765259, ANN loss : 1.582055926322937, Total loss : 75.69901275634766
# learning rate A :  tf.Tensor(9.9701225e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 54 is 0.0558 sec
# train AE loss : 0.7594898343086243, train ANN loss : 1.6956448554992676
# AE loss : 0.740034282207489, ANN loss : 1.5763850212097168, Total loss : 75.5798110961914
# learning rate A :  tf.Tensor(9.9701225e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 55 is 0.0564 sec
# train AE loss : 0.7582313418388367, train ANN loss : 1.6803064346313477
# AE loss : 0.7399399876594543, ANN loss : 1.5763764381408691, Total loss : 75.57037353515625
# learning rate A :  tf.Tensor(9.969912e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 56 is 0.0575 sec
# train AE loss : 0.7581287622451782, train ANN loss : 1.6973589658737183
# AE loss : 0.7398458123207092, ANN loss : 1.5763680934906006, Total loss : 75.56095123291016
# learning rate A :  tf.Tensor(9.969702e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 57 is 0.1860 sec
# train AE loss : 0.7580263018608093, train ANN loss : 1.6922990083694458
# AE loss : 0.7397516369819641, ANN loss : 1.5763593912124634, Total loss : 75.55152130126953
# learning rate A :  tf.Tensor(9.969492e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 58 is 0.0588 sec
# train AE loss : 0.7579240202903748, train ANN loss : 1.6765390634536743
# AE loss : 0.7383826375007629, ANN loss : 1.570671796798706, Total loss : 75.408935546875
# learning rate A :  tf.Tensor(9.969492e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 59 is 0.0574 sec
# train AE loss : 0.7564002871513367, train ANN loss : 1.6979115009307861
# AE loss : 0.7371675968170166, ANN loss : 1.5652821063995361, Total loss : 75.28204345703125
# learning rate A :  tf.Tensor(9.969492e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 60 is 0.0579 sec
# train AE loss : 0.7550487518310547, train ANN loss : 1.6931973695755005
# AE loss : 0.7370719909667969, ANN loss : 1.5652737617492676, Total loss : 75.27246856689453
# learning rate A :  tf.Tensor(9.969282e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 61 is 0.0574 sec
# train AE loss : 0.7549449801445007, train ANN loss : 1.6759047508239746
# AE loss : 0.7369764447212219, ANN loss : 1.5652656555175781, Total loss : 75.26290893554688
# learning rate A :  tf.Tensor(9.969072e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 62 is 0.0560 sec
# train AE loss : 0.7548414468765259, train ANN loss : 1.6910336017608643
# AE loss : 0.7368810176849365, ANN loss : 1.56525719165802, Total loss : 75.25336456298828
# learning rate A :  tf.Tensor(9.9688616e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 63 is 0.0550 sec
# train AE loss : 0.7547379732131958, train ANN loss : 1.674699068069458
# AE loss : 0.7354540824890137, ANN loss : 1.5600355863571167, Total loss : 75.1054458618164
# learning rate A :  tf.Tensor(9.9688616e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 64 is 0.0570 sec
# train AE loss : 0.7531220316886902, train ANN loss : 1.6780102252960205
# AE loss : 0.7340278625488281, ANN loss : 1.5549086332321167, Total loss : 74.95769500732422
# learning rate A :  tf.Tensor(9.9688616e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 65 is 0.0586 sec
# train AE loss : 0.75153648853302, train ANN loss : 1.6666334867477417
# AE loss : 0.732548177242279, ANN loss : 1.5499517917633057, Total loss : 74.80477142333984
# learning rate A :  tf.Tensor(9.9688616e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 66 is 0.0577 sec
# train AE loss : 0.7498795390129089, train ANN loss : 1.652814507484436
# AE loss : 0.7307053804397583, ANN loss : 1.5449739694595337, Total loss : 74.61551666259766
# learning rate A :  tf.Tensor(9.9688616e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 67 is 0.0570 sec
# train AE loss : 0.7478305697441101, train ANN loss : 1.6603105068206787
# AE loss : 0.7306036353111267, ANN loss : 1.544966220855713, Total loss : 74.60533142089844
# learning rate A :  tf.Tensor(9.968652e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 68 is 0.0550 sec
# train AE loss : 0.7477201223373413, train ANN loss : 1.6557551622390747
# AE loss : 0.7305020093917847, ANN loss : 1.544958472251892, Total loss : 74.59516143798828
# learning rate A :  tf.Tensor(9.968442e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 69 is 0.0579 sec
# train AE loss : 0.7476098537445068, train ANN loss : 1.6468079090118408
# AE loss : 0.7304004430770874, ANN loss : 1.5449507236480713, Total loss : 74.58499908447266
# learning rate A :  tf.Tensor(9.9682315e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 70 is 0.0554 sec
# train AE loss : 0.7474997043609619, train ANN loss : 1.6561279296875
# AE loss : 0.7302989363670349, ANN loss : 1.544942855834961, Total loss : 74.57483673095703
# learning rate A :  tf.Tensor(9.968022e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 71 is 0.0554 sec
# train AE loss : 0.7473896741867065, train ANN loss : 1.6573859453201294
# AE loss : 0.7284566760063171, ANN loss : 1.5400453805923462, Total loss : 74.38571166992188
# learning rate A :  tf.Tensor(9.968022e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 72 is 0.0573 sec
# train AE loss : 0.7453514337539673, train ANN loss : 1.6665961742401123
# AE loss : 0.7283564805984497, ANN loss : 1.5400381088256836, Total loss : 74.37568664550781
# learning rate A :  tf.Tensor(9.967812e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 73 is 0.0575 sec
# train AE loss : 0.7452428340911865, train ANN loss : 1.6457619667053223
# AE loss : 0.7282564043998718, ANN loss : 1.540030598640442, Total loss : 74.36566162109375
# learning rate A :  tf.Tensor(9.967601e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 74 is 0.0558 sec
# train AE loss : 0.745134174823761, train ANN loss : 1.6619234085083008
# AE loss : 0.7264986634254456, ANN loss : 1.535329818725586, Total loss : 74.18518829345703
# learning rate A :  tf.Tensor(9.967601e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 75 is 0.0570 sec
# train AE loss : 0.7431877851486206, train ANN loss : 1.651046872138977
# AE loss : 0.7263996005058289, ANN loss : 1.5353232622146606, Total loss : 74.17527770996094
# learning rate A :  tf.Tensor(9.967391e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 76 is 0.0562 sec
# train AE loss : 0.7430805563926697, train ANN loss : 1.6625019311904907
# AE loss : 0.7263005375862122, ANN loss : 1.535316824913025, Total loss : 74.16536712646484
# learning rate A :  tf.Tensor(9.9671815e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 77 is 0.0574 sec
# train AE loss : 0.742973268032074, train ANN loss : 1.6588726043701172
# AE loss : 0.726201593875885, ANN loss : 1.5353103876113892, Total loss : 74.15547180175781
# learning rate A :  tf.Tensor(9.966971e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 78 is 0.0564 sec
# train AE loss : 0.7428662180900574, train ANN loss : 1.6496151685714722
# AE loss : 0.7261028289794922, ANN loss : 1.5353039503097534, Total loss : 74.14558410644531
# learning rate A :  tf.Tensor(9.966761e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 79 is 0.0559 sec
# train AE loss : 0.7427594065666199, train ANN loss : 1.6474552154541016
# AE loss : 0.7243565320968628, ANN loss : 1.5308127403259277, Total loss : 73.96646881103516
# learning rate A :  tf.Tensor(9.966761e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 80 is 0.0585 sec
# train AE loss : 0.7408448457717896, train ANN loss : 1.660154938697815
# AE loss : 0.7242591977119446, ANN loss : 1.5308067798614502, Total loss : 73.95672607421875
# learning rate A :  tf.Tensor(9.966551e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 81 is 0.0556 sec
# train AE loss : 0.7407394647598267, train ANN loss : 1.656860113143921
# AE loss : 0.7241619229316711, ANN loss : 1.5308008193969727, Total loss : 73.9469985961914
# learning rate A :  tf.Tensor(9.9663404e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 82 is 0.0554 sec
# train AE loss : 0.7406340837478638, train ANN loss : 1.6580430269241333
# AE loss : 0.7240647673606873, ANN loss : 1.5307948589324951, Total loss : 73.93727111816406
# learning rate A :  tf.Tensor(9.966131e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 83 is 0.0558 sec
# train AE loss : 0.74052894115448, train ANN loss : 1.6475200653076172
# AE loss : 0.7226892113685608, ANN loss : 1.5263102054595947, Total loss : 73.79523468017578
# learning rate A :  tf.Tensor(9.966131e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 84 is 0.0591 sec
# train AE loss : 0.739015519618988, train ANN loss : 1.6351821422576904
# AE loss : 0.7225929498672485, ANN loss : 1.5263047218322754, Total loss : 73.78559875488281
# learning rate A :  tf.Tensor(9.9659206e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 85 is 0.0565 sec
# train AE loss : 0.738911509513855, train ANN loss : 1.661047339439392
# AE loss : 0.7224969267845154, ANN loss : 1.526299238204956, Total loss : 73.77599334716797
# learning rate A :  tf.Tensor(9.96571e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 86 is 0.0562 sec
# train AE loss : 0.7388074994087219, train ANN loss : 1.6430468559265137
# AE loss : 0.7224010229110718, ANN loss : 1.5262939929962158, Total loss : 73.76639556884766
# learning rate A :  tf.Tensor(9.965501e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 87 is 0.0569 sec
# train AE loss : 0.7387036085128784, train ANN loss : 1.6443932056427002
# AE loss : 0.7223051190376282, ANN loss : 1.5262885093688965, Total loss : 73.75679779052734
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 88 is 0.0561 sec
# train AE loss : 0.7385998964309692, train ANN loss : 1.6324869394302368
# AE loss : 0.7213630080223083, ANN loss : 1.5217716693878174, Total loss : 73.65807342529297
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 89 is 0.0566 sec
# train AE loss : 0.7375867962837219, train ANN loss : 1.646484136581421
# AE loss : 0.7206605672836304, ANN loss : 1.5174516439437866, Total loss : 73.58351135253906
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 90 is 0.0570 sec
# train AE loss : 0.7368360161781311, train ANN loss : 1.655653715133667
# AE loss : 0.7201125025749207, ANN loss : 1.5133097171783447, Total loss : 73.5245590209961
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 91 is 0.0583 sec
# train AE loss : 0.7362357378005981, train ANN loss : 1.6202890872955322
# AE loss : 0.719482421875, ANN loss : 1.509168267250061, Total loss : 73.45741271972656
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 92 is 0.0577 sec
# train AE loss : 0.7355626821517944, train ANN loss : 1.605334758758545
# AE loss : 0.7189265489578247, ANN loss : 1.5049667358398438, Total loss : 73.39762878417969
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 93 is 0.0577 sec
# train AE loss : 0.7349686622619629, train ANN loss : 1.6285903453826904
# AE loss : 0.7184241414070129, ANN loss : 1.5009928941726685, Total loss : 73.3434066772461
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 94 is 0.0582 sec
# train AE loss : 0.7344233393669128, train ANN loss : 1.6186728477478027
# AE loss : 0.7178647518157959, ANN loss : 1.4974380731582642, Total loss : 73.2839126586914
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 95 is 0.0593 sec
# train AE loss : 0.7337957620620728, train ANN loss : 1.6200652122497559
# AE loss : 0.7171013951301575, ANN loss : 1.4939649105072021, Total loss : 73.20409393310547
# learning rate A :  tf.Tensor(9.9652905e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 96 is 0.0579 sec
# train AE loss : 0.7329198718070984, train ANN loss : 1.5843863487243652
# AE loss : 0.7170080542564392, ANN loss : 1.4939604997634888, Total loss : 73.19476318359375
# learning rate A :  tf.Tensor(9.965081e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 97 is 0.0569 sec
# train AE loss : 0.732818603515625, train ANN loss : 1.6185764074325562
# AE loss : 0.7162052989006042, ANN loss : 1.490500569343567, Total loss : 73.11103057861328
# learning rate A :  tf.Tensor(9.965081e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 98 is 0.0583 sec
# train AE loss : 0.7318832278251648, train ANN loss : 1.6102386713027954
# AE loss : 0.7155632376670837, ANN loss : 1.4870266914367676, Total loss : 73.04335021972656
# learning rate A :  tf.Tensor(9.965081e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 99 is 0.0654 sec
# train AE loss : 0.7311424016952515, train ANN loss : 1.5846774578094482
# AE loss : 0.7154718637466431, ANN loss : 1.4870229959487915, Total loss : 73.03421783447266
# learning rate A :  tf.Tensor(9.964871e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 100 is 0.0553 sec
# train AE loss : 0.7310432195663452, train ANN loss : 1.5981833934783936
# AE loss : 0.7153807282447815, ANN loss : 1.4870191812515259, Total loss : 73.02509307861328
# learning rate A :  tf.Tensor(9.9646604e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 101 is 0.0557 sec
# train AE loss : 0.7309441566467285, train ANN loss : 1.5967824459075928
# AE loss : 0.7152897715568542, ANN loss : 1.4870154857635498, Total loss : 73.0159912109375
# learning rate A :  tf.Tensor(9.964451e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 102 is 0.0572 sec
# train AE loss : 0.7308453321456909, train ANN loss : 1.6138304471969604
# AE loss : 0.7148433327674866, ANN loss : 1.4833240509033203, Total loss : 72.96765899658203
# learning rate A :  tf.Tensor(9.964451e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 103 is 0.0569 sec
# train AE loss : 0.7303158640861511, train ANN loss : 1.5822418928146362
# AE loss : 0.7147528529167175, ANN loss : 1.4833208322525024, Total loss : 72.95861053466797
# learning rate A :  tf.Tensor(9.964241e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 104 is 0.0552 sec
# train AE loss : 0.7302176356315613, train ANN loss : 1.5994452238082886
# AE loss : 0.7146625518798828, ANN loss : 1.4833173751831055, Total loss : 72.94956970214844
# learning rate A :  tf.Tensor(9.964031e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 105 is 0.0552 sec
# train AE loss : 0.730119526386261, train ANN loss : 1.605948805809021
# AE loss : 0.7145723104476929, ANN loss : 1.4833139181137085, Total loss : 72.94054412841797
# learning rate A :  tf.Tensor(9.963821e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 106 is 0.0576 sec
# train AE loss : 0.730021595954895, train ANN loss : 1.5778017044067383
# AE loss : 0.7144822478294373, ANN loss : 1.4833108186721802, Total loss : 72.93153381347656
# learning rate A :  tf.Tensor(9.963611e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 107 is 0.0554 sec
# train AE loss : 0.7299237847328186, train ANN loss : 1.595725178718567
# AE loss : 0.7140054702758789, ANN loss : 1.479602336883545, Total loss : 72.8801498413086
# learning rate A :  tf.Tensor(9.963611e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 108 is 0.0568 sec
# train AE loss : 0.7293487191200256, train ANN loss : 1.6071754693984985
# AE loss : 0.713483452796936, ANN loss : 1.4758689403533936, Total loss : 72.82421112060547
# learning rate A :  tf.Tensor(9.963611e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 109 is 0.0576 sec
# train AE loss : 0.7287152409553528, train ANN loss : 1.5677546262741089
# AE loss : 0.7129742503166199, ANN loss : 1.4719359874725342, Total loss : 72.76936340332031
# learning rate A :  tf.Tensor(9.963611e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 110 is 0.0585 sec
# train AE loss : 0.7280981540679932, train ANN loss : 1.5748260021209717
# AE loss : 0.7128855586051941, ANN loss : 1.471934199333191, Total loss : 72.76049041748047
# learning rate A :  tf.Tensor(9.963401e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 111 is 0.0640 sec
# train AE loss : 0.7280018329620361, train ANN loss : 1.5637567043304443
# AE loss : 0.7127968072891235, ANN loss : 1.471932291984558, Total loss : 72.7516098022461
# learning rate A :  tf.Tensor(9.963191e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 112 is 0.0554 sec
# train AE loss : 0.7279055118560791, train ANN loss : 1.6105775833129883
# AE loss : 0.7127082347869873, ANN loss : 1.4719302654266357, Total loss : 72.74275207519531
# learning rate A :  tf.Tensor(9.962981e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 113 is 0.0605 sec
# train AE loss : 0.727809488773346, train ANN loss : 1.5862329006195068
# AE loss : 0.7122370004653931, ANN loss : 1.4680585861206055, Total loss : 72.69175720214844
# learning rate A :  tf.Tensor(9.962981e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 114 is 0.0584 sec
# train AE loss : 0.727234423160553, train ANN loss : 1.58417809009552
# AE loss : 0.7120171189308167, ANN loss : 1.4641146659851074, Total loss : 72.66583251953125
# learning rate A :  tf.Tensor(9.962981e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 115 is 0.0567 sec
# train AE loss : 0.7269731163978577, train ANN loss : 1.5708668231964111
# AE loss : 0.7119293212890625, ANN loss : 1.4641132354736328, Total loss : 72.65704345703125
# learning rate A :  tf.Tensor(9.9627716e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 116 is 0.0553 sec
# train AE loss : 0.7268778085708618, train ANN loss : 1.5670876502990723
# AE loss : 0.7118417620658875, ANN loss : 1.4641119241714478, Total loss : 72.64828491210938
# learning rate A :  tf.Tensor(9.962561e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 117 is 0.0576 sec
# train AE loss : 0.7267826795578003, train ANN loss : 1.555077075958252
# AE loss : 0.7117542028427124, ANN loss : 1.4641103744506836, Total loss : 72.63953399658203
# learning rate A :  tf.Tensor(9.962352e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 118 is 0.0564 sec
# train AE loss : 0.7266876101493835, train ANN loss : 1.565110206604004
# AE loss : 0.7116667032241821, ANN loss : 1.4641093015670776, Total loss : 72.63077545166016
# learning rate A :  tf.Tensor(9.962142e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 119 is 0.0564 sec
# train AE loss : 0.7265928387641907, train ANN loss : 1.5913550853729248
# AE loss : 0.7115795612335205, ANN loss : 1.464107871055603, Total loss : 72.62206268310547
# learning rate A :  tf.Tensor(9.961931e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 120 is 0.0582 sec
# train AE loss : 0.7264981865882874, train ANN loss : 1.5654535293579102
# AE loss : 0.7114924788475037, ANN loss : 1.4641064405441284, Total loss : 72.61334991455078
# learning rate A :  tf.Tensor(9.961722e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 121 is 0.0564 sec
# train AE loss : 0.7264037132263184, train ANN loss : 1.5688420534133911
# AE loss : 0.7114055156707764, ANN loss : 1.4641053676605225, Total loss : 72.60466003417969
# learning rate A :  tf.Tensor(9.961512e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 122 is 0.0562 sec
# train AE loss : 0.7263092994689941, train ANN loss : 1.565564751625061
# AE loss : 0.7113186717033386, ANN loss : 1.4641038179397583, Total loss : 72.5959701538086
# learning rate A :  tf.Tensor(9.961302e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 123 is 0.0563 sec
# train AE loss : 0.7262150645256042, train ANN loss : 1.564038872718811
# AE loss : 0.7112320065498352, ANN loss : 1.464102864265442, Total loss : 72.5873031616211
# learning rate A :  tf.Tensor(9.961092e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 124 is 0.0578 sec
# train AE loss : 0.7261210680007935, train ANN loss : 1.5749459266662598
# AE loss : 0.7111454606056213, ANN loss : 1.4641016721725464, Total loss : 72.57864379882812
# learning rate A :  tf.Tensor(9.960883e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 125 is 0.0561 sec
# train AE loss : 0.7260270118713379, train ANN loss : 1.5688008069992065
# AE loss : 0.7110590934753418, ANN loss : 1.4641003608703613, Total loss : 72.57001495361328
# learning rate A :  tf.Tensor(9.960672e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 126 is 0.0566 sec
# train AE loss : 0.7259331345558167, train ANN loss : 1.5857372283935547
# AE loss : 0.710972785949707, ANN loss : 1.4640991687774658, Total loss : 72.56137084960938
# learning rate A :  tf.Tensor(9.960462e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 127 is 0.0572 sec
# train AE loss : 0.7258394956588745, train ANN loss : 1.569726824760437
# AE loss : 0.710886538028717, ANN loss : 1.4640979766845703, Total loss : 72.5527572631836
# learning rate A :  tf.Tensor(9.960253e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 128 is 0.0596 sec
# train AE loss : 0.7257459759712219, train ANN loss : 1.578537940979004
# AE loss : 0.7108005881309509, ANN loss : 1.4640967845916748, Total loss : 72.54415130615234
# learning rate A :  tf.Tensor(9.9600424e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 129 is 0.0579 sec
# train AE loss : 0.7256525754928589, train ANN loss : 1.5855839252471924
# AE loss : 0.7106638550758362, ANN loss : 1.4599778652191162, Total loss : 72.52635955810547
# learning rate A :  tf.Tensor(9.9600424e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 130 is 0.0589 sec
# train AE loss : 0.7254992723464966, train ANN loss : 1.5594308376312256
# AE loss : 0.7105958461761475, ANN loss : 1.455872893333435, Total loss : 72.51545715332031
# learning rate A :  tf.Tensor(9.9600424e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 131 is 0.0593 sec
# train AE loss : 0.725407600402832, train ANN loss : 1.5745058059692383
# AE loss : 0.710509717464447, ANN loss : 1.4558719396591187, Total loss : 72.50684356689453
# learning rate A :  tf.Tensor(9.959833e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 132 is 0.0570 sec
# train AE loss : 0.7253140211105347, train ANN loss : 1.5582221746444702
# AE loss : 0.7106828689575195, ANN loss : 1.4519084692001343, Total loss : 72.52019500732422
# learning rate A :  tf.Tensor(9.959833e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 133 is 0.0565 sec
# train AE loss : 0.7255098223686218, train ANN loss : 1.570622205734253
# AE loss : 0.7110003232955933, ANN loss : 1.4481662511825562, Total loss : 72.5481948852539
# learning rate A :  tf.Tensor(9.959833e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 134 is 0.0573 sec
# train AE loss : 0.7258735299110413, train ANN loss : 1.561819076538086
# AE loss : 0.7111054062843323, ANN loss : 1.4448113441467285, Total loss : 72.55535125732422
# learning rate A :  tf.Tensor(9.959833e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 135 is 0.0593 sec
# train AE loss : 0.725993812084198, train ANN loss : 1.5391640663146973
# AE loss : 0.7109066843986511, ANN loss : 1.4414209127426147, Total loss : 72.53208923339844
# learning rate A :  tf.Tensor(9.959833e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 136 is 0.0572 sec
# train AE loss : 0.7257727980613708, train ANN loss : 1.56298828125
# AE loss : 0.7108377814292908, ANN loss : 1.4382117986679077, Total loss : 72.5219955444336
# learning rate A :  tf.Tensor(9.959833e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# ...
# Time for epoch 1955 is 0.0582 sec
# train AE loss : 1.4176524877548218, train ANN loss : 0.6060276031494141
# AE loss : 1.3825643062591553, ANN loss : 0.41243746876716614, Total loss : 138.66885375976562
# learning rate A :  tf.Tensor(9.7712844e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1956 is 0.0565 sec
# train AE loss : 1.404189109802246, train ANN loss : 0.6049785017967224
# AE loss : 1.3699579238891602, ANN loss : 0.4121313691139221, Total loss : 137.40792846679688
# learning rate A :  tf.Tensor(9.771078e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1957 is 0.0583 sec
# train AE loss : 1.391035795211792, train ANN loss : 0.6682628989219666
# AE loss : 1.357907772064209, ANN loss : 0.411852091550827, Total loss : 136.20262145996094
# learning rate A :  tf.Tensor(9.7708726e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1958 is 0.0571 sec
# train AE loss : 1.3783332109451294, train ANN loss : 0.6459740996360779
# AE loss : 1.3661149740219116, ANN loss : 0.4081176221370697, Total loss : 137.0196075439453
# learning rate A :  tf.Tensor(9.7708726e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1959 is 0.0585 sec
# train AE loss : 1.387044906616211, train ANN loss : 0.6560099124908447
# AE loss : 1.3697823286056519, ANN loss : 0.40218818187713623, Total loss : 137.3804168701172
# learning rate A :  tf.Tensor(9.7708726e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1960 is 0.0588 sec
# train AE loss : 1.3900331258773804, train ANN loss : 0.6200522184371948
# AE loss : 1.36501944065094, ANN loss : 0.39481067657470703, Total loss : 136.89675903320312
# learning rate A :  tf.Tensor(9.7708726e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1961 is 0.0586 sec
# train AE loss : 1.381644368171692, train ANN loss : 0.622044026851654
# AE loss : 1.3540055751800537, ANN loss : 0.3945777714252472, Total loss : 135.79513549804688
# learning rate A :  tf.Tensor(9.770667e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1962 is 0.0564 sec
# train AE loss : 1.3697428703308105, train ANN loss : 0.6115798950195312
# AE loss : 1.3599995374679565, ANN loss : 0.392045795917511, Total loss : 136.39199829101562
# learning rate A :  tf.Tensor(9.770667e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1963 is 0.0579 sec
# train AE loss : 1.372488260269165, train ANN loss : 0.6235101819038391
# AE loss : 1.3501001596450806, ANN loss : 0.391914039850235, Total loss : 135.40191650390625
# learning rate A :  tf.Tensor(9.770461e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1964 is 0.0579 sec
# train AE loss : 1.3620657920837402, train ANN loss : 0.6289479732513428
# AE loss : 1.3613756895065308, ANN loss : 0.3923198878765106, Total loss : 136.52989196777344
# learning rate A :  tf.Tensor(9.770461e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1965 is 0.0589 sec
# train AE loss : 1.3725842237472534, train ANN loss : 0.6059111952781677
# AE loss : 1.3721848726272583, ANN loss : 0.39314380288124084, Total loss : 137.61163330078125
# learning rate A :  tf.Tensor(9.770461e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1966 is 0.0620 sec
# train AE loss : 1.3856689929962158, train ANN loss : 0.6291475892066956
# AE loss : 1.3921505212783813, ANN loss : 0.39667969942092896, Total loss : 139.6117401123047
# learning rate A :  tf.Tensor(9.770461e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1967 is 0.0587 sec
# train AE loss : 1.408063530921936, train ANN loss : 0.6161034107208252
# AE loss : 1.3786031007766724, ANN loss : 0.39624759554862976, Total loss : 138.2565460205078
# learning rate A :  tf.Tensor(9.770255e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1968 is 0.0577 sec
# train AE loss : 1.3940731287002563, train ANN loss : 0.6441464424133301
# AE loss : 1.3656997680664062, ANN loss : 0.3958655595779419, Total loss : 136.96583557128906
# learning rate A :  tf.Tensor(9.770049e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1969 is 0.0563 sec
# train AE loss : 1.3807882070541382, train ANN loss : 0.6418069005012512
# AE loss : 1.3902249336242676, ANN loss : 0.4035019278526306, Total loss : 139.42599487304688
# learning rate A :  tf.Tensor(9.770049e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1970 is 0.0570 sec
# train AE loss : 1.4070732593536377, train ANN loss : 0.6440334320068359
# AE loss : 1.3886045217514038, ANN loss : 0.40721064805984497, Total loss : 139.26766967773438
# learning rate A :  tf.Tensor(9.770049e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1971 is 0.0579 sec
# train AE loss : 1.4068149328231812, train ANN loss : 0.6264635920524597
# AE loss : 1.3740367889404297, ANN loss : 0.40657955408096313, Total loss : 137.81027221679688
# learning rate A :  tf.Tensor(9.769843e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1972 is 0.0564 sec
# train AE loss : 1.3920388221740723, train ANN loss : 0.6182308793067932
# AE loss : 1.360106348991394, ANN loss : 0.40601587295532227, Total loss : 136.41664123535156
# learning rate A :  tf.Tensor(9.769637e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1973 is 0.0567 sec
# train AE loss : 1.3778152465820312, train ANN loss : 0.6508628129959106
# AE loss : 1.3476941585540771, ANN loss : 0.40762102603912354, Total loss : 135.17703247070312
# learning rate A :  tf.Tensor(9.769637e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1974 is 0.0573 sec
# train AE loss : 1.363111138343811, train ANN loss : 0.6180492043495178
# AE loss : 1.3493058681488037, ANN loss : 0.405249685049057, Total loss : 135.33583068847656
# learning rate A :  tf.Tensor(9.769637e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1975 is 0.0591 sec
# train AE loss : 1.3610918521881104, train ANN loss : 0.6296721696853638
# AE loss : 1.3394571542739868, ANN loss : 0.40512824058532715, Total loss : 134.35084533691406
# learning rate A :  tf.Tensor(9.769431e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1976 is 0.0562 sec
# train AE loss : 1.350696325302124, train ANN loss : 0.6855013966560364
# AE loss : 1.3461167812347412, ANN loss : 0.40175482630729675, Total loss : 135.01344299316406
# learning rate A :  tf.Tensor(9.769431e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1977 is 0.0570 sec
# train AE loss : 1.357873797416687, train ANN loss : 0.6501543521881104
# AE loss : 1.3547840118408203, ANN loss : 0.39989787340164185, Total loss : 135.87828063964844
# learning rate A :  tf.Tensor(9.769431e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1978 is 0.0587 sec
# train AE loss : 1.36902916431427, train ANN loss : 0.6548564434051514
# AE loss : 1.3447109460830688, ANN loss : 0.39979124069213867, Total loss : 134.8708953857422
# learning rate A :  tf.Tensor(9.769225e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1979 is 0.0577 sec
# train AE loss : 1.3582570552825928, train ANN loss : 0.6421926021575928
# AE loss : 1.3349851369857788, ANN loss : 0.39968863129615784, Total loss : 133.89822387695312
# learning rate A :  tf.Tensor(9.769019e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1980 is 0.0562 sec
# train AE loss : 1.347918152809143, train ANN loss : 0.6466940641403198
# AE loss : 1.3255314826965332, ANN loss : 0.3995915353298187, Total loss : 132.95272827148438
# learning rate A :  tf.Tensor(9.768813e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1981 is 0.0566 sec
# train AE loss : 1.337888240814209, train ANN loss : 0.6366977691650391
# AE loss : 1.316343069076538, ANN loss : 0.39949852228164673, Total loss : 132.03379821777344
# learning rate A :  tf.Tensor(9.7686076e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1982 is 0.0577 sec
# train AE loss : 1.32814359664917, train ANN loss : 0.6070594787597656
# AE loss : 1.3074302673339844, ANN loss : 0.39940881729125977, Total loss : 131.14244079589844
# learning rate A :  tf.Tensor(9.768401e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1983 is 0.0566 sec
# train AE loss : 1.318682312965393, train ANN loss : 0.5986279845237732
# AE loss : 1.2987804412841797, ANN loss : 0.39932191371917725, Total loss : 130.2773895263672
# learning rate A :  tf.Tensor(9.768196e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1984 is 0.0615 sec
# train AE loss : 1.309491515159607, train ANN loss : 0.6221531629562378
# AE loss : 1.3089871406555176, ANN loss : 0.4003548324108124, Total loss : 131.29905700683594
# learning rate A :  tf.Tensor(9.768196e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1985 is 0.0584 sec
# train AE loss : 1.324176549911499, train ANN loss : 0.6785306930541992
# AE loss : 1.3269838094711304, ANN loss : 0.4049583375453949, Total loss : 133.10333251953125
# learning rate A :  tf.Tensor(9.768196e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1986 is 0.0597 sec
# train AE loss : 1.3477997779846191, train ANN loss : 0.6100008487701416
# AE loss : 1.3158494234085083, ANN loss : 0.40465185046195984, Total loss : 131.98960876464844
# learning rate A :  tf.Tensor(9.76799e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1987 is 0.0563 sec
# train AE loss : 1.33563232421875, train ANN loss : 0.6466184854507446
# AE loss : 1.3052589893341064, ANN loss : 0.4043690860271454, Total loss : 130.93026733398438
# learning rate A :  tf.Tensor(9.767784e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1988 is 0.0656 sec
# train AE loss : 1.3240619897842407, train ANN loss : 0.6410380601882935
# AE loss : 1.2952631711959839, ANN loss : 0.40411779284477234, Total loss : 129.93043518066406
# learning rate A :  tf.Tensor(9.767578e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1989 is 0.0570 sec
# train AE loss : 1.3131462335586548, train ANN loss : 0.6247859597206116
# AE loss : 1.314551591873169, ANN loss : 0.41057634353637695, Total loss : 131.86572265625
# learning rate A :  tf.Tensor(9.767578e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1990 is 0.0577 sec
# train AE loss : 1.3362135887145996, train ANN loss : 0.6007874608039856
# AE loss : 1.3290531635284424, ANN loss : 0.41460147500038147, Total loss : 133.31991577148438
# learning rate A :  tf.Tensor(9.767578e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1991 is 0.0576 sec
# train AE loss : 1.3512892723083496, train ANN loss : 0.6327503323554993
# AE loss : 1.3168901205062866, ANN loss : 0.4142012894153595, Total loss : 132.10321044921875
# learning rate A :  tf.Tensor(9.767372e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1992 is 0.0560 sec
# train AE loss : 1.3385425806045532, train ANN loss : 0.637824535369873
# AE loss : 1.3053410053253174, ANN loss : 0.4138322174549103, Total loss : 130.94793701171875
# learning rate A :  tf.Tensor(9.767167e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1993 is 0.0581 sec
# train AE loss : 1.3262485265731812, train ANN loss : 0.6565431356430054
# AE loss : 1.3131483793258667, ANN loss : 0.4147888720035553, Total loss : 131.72962951660156
# learning rate A :  tf.Tensor(9.767167e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1994 is 0.0575 sec
# train AE loss : 1.3323414325714111, train ANN loss : 0.6200515031814575
# AE loss : 1.3026951551437378, ANN loss : 0.41456714272499084, Total loss : 130.68409729003906
# learning rate A :  tf.Tensor(9.76696e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1995 is 0.0558 sec
# train AE loss : 1.3209667205810547, train ANN loss : 0.6104669570922852
# AE loss : 1.3139276504516602, ANN loss : 0.4087901711463928, Total loss : 131.80154418945312
# learning rate A :  tf.Tensor(9.76696e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1996 is 0.0570 sec
# train AE loss : 1.3308366537094116, train ANN loss : 0.6106234192848206
# AE loss : 1.3294774293899536, ANN loss : 0.4000093936920166, Total loss : 133.34774780273438
# learning rate A :  tf.Tensor(9.76696e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1997 is 0.0588 sec
# train AE loss : 1.3465063571929932, train ANN loss : 0.5998142957687378
# AE loss : 1.3192414045333862, ANN loss : 0.39984431862831116, Total loss : 132.323974609375
# learning rate A :  tf.Tensor(9.766755e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1998 is 0.0562 sec
# train AE loss : 1.335576057434082, train ANN loss : 0.6695339679718018
# AE loss : 1.3373141288757324, ANN loss : 0.39477792382240295, Total loss : 134.12619018554688
# learning rate A :  tf.Tensor(9.766755e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 1999 is 0.0572 sec
# train AE loss : 1.3554800748825073, train ANN loss : 0.6257221698760986
# AE loss : 1.3552427291870117, ANN loss : 0.3925771415233612, Total loss : 135.91685485839844
# learning rate A :  tf.Tensor(9.766755e-05, shape=(), dtype=float32)
# learning rate B :  <tf.Variable 'learning_rate:0' shape=() dtype=float32, numpy=0.001>
# Time for epoch 2000 is 0.0613 sec

# %%
val_latent = model_down(val_x)
from sklearn import manifold, datasets
import matplotlib.pyplot as plt
train_val_split = np.random.rand(len(val_latent)) < 0.4
X_tsne = manifold.TSNE(n_components=2, init='pca', n_iter=5000, method='exact').fit_transform(val_latent[train_val_split])
y = val_y[train_val_split].argmax(axis=1).reshape([-1,1])
x_min, x_max = X_tsne.min(0), X_tsne.max(0)
X_norm = (X_tsne - x_min) / (x_max - x_min)
plt.figure(figsize=(20, 20))
for i in range(X_norm.shape[0]):
    plt.text(X_norm[i, 0], X_norm[i, 1], str(y[i,0]), color=plt.cm.Set1(y[i,0]), 
             fontdict={'weight': 'bold', 'size': 9})
plt.xticks([])
plt.yticks([])
plt.savefig("result_mag/pca_result_latent16_exp11_3")
plt.show()

# %%
y = val_y[train_val_split].argmax(axis=1).reshape([-1,1])

# %%
y.shape
# Out:
# (143, 1)

# %%
model_encoder_decoder_ann.weights[0][0]
# Out:
# <tf.Tensor: id=1112230, shape=(8,), dtype=float32, numpy=
# array([ 0.06707124, -0.06958992, -0.08077073,  0.07173584, -0.00723271,
#        -0.05953319,  0.11224787,  0.03083349], dtype=float32)>

# %%
model_down.weights[0][0]
# Out:
# <tf.Tensor: id=1112235, shape=(8,), dtype=float32, numpy=
# array([ 0.06707124, -0.06958992, -0.08077073,  0.07173584, -0.00723271,
#        -0.05953319,  0.11224787,  0.03083349], dtype=float32)>
